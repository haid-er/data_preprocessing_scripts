# %%
import os
import re

def remove_any_parentheses(base_path):
    # Matches: optional space + (anything) 
    pattern = re.compile(r"\s*\([^)]*\)")

    for dirpath, _, filenames in os.walk(base_path):
        for filename in filenames:
            if pattern.search(filename):
                old_path = os.path.join(dirpath, filename)
                new_filename = pattern.sub('', filename).strip()
                new_path = os.path.join(dirpath, new_filename)

                if not os.path.exists(new_path):
                    os.rename(old_path, new_path)
                    print(f"✅ Renamed: {old_path} → {new_path}")
                else:
                    print(f"⚠️ Skipped (target exists): {old_path} → {new_path}")

    print("\n🎉 All matching files processed.")

# =======================
# Run
# =======================
if __name__ == "__main__":
    base_path = r"C:\Users\hp\Downloads\DS_AF - Copy\DS_AF"
    if os.path.exists(base_path):
        print(f"\n🔄 Renaming files in: {base_path}")
        remove_any_parentheses(base_path)
        print("\n✅ All done.")
    else:
        print("❌ The path does not exist.")

# %% [raw]
# 1- remove duplicated files
# 2- delete unwanted sensors
# 3- empty files ( delete with partivular event)
# 4- emplty files ( delete without events)
# 5- create copy
# 6- segmentation

# %% [markdown]
# # Create log for duplicate

# %%
import os
import re

def find_duplicate_named_files(base_path):
    duplicate_log = r"E:\DS_RAW_COMPLETE\logs\5-actual_duplicates_after_deletion_log.txt"
    orphan_log = r"E:\DS_RAW_COMPLETE\logs\orphan_duplicate_named_log.txt"

    original_files = set()
    duplicate_named_files = []

    # Walk and collect
    for dirpath, _, filenames in os.walk(base_path):
        for filename in filenames:
            full_path = os.path.join(dirpath, filename)
            original_files.add(full_path)

            # Match files with suffix like (1), (2), (3)
            match = re.search(r"(.*?)(?: ?\((\d+)\))(\.\w+)$", filename)
            if match:
                duplicate_named_files.append((match.group(1) + match.group(3), full_path))

    # Compare with originals
    with open(duplicate_log, 'w') as dlog, open(orphan_log, 'w') as olog:
        for original_name, dup_full_path in duplicate_named_files:
            original_full_path = os.path.join(os.path.dirname(dup_full_path), original_name)
            if os.path.exists(original_full_path):
                dlog.write(f"{dup_full_path}\n")
            else:
                olog.write(f"{dup_full_path}\n")

    print("✅ Scanning complete.")
    print(f"📄 Actual duplicates logged in: {duplicate_log}")
    print(f"📄 Orphan-like duplicate names logged in: {orphan_log}")

# =======================
# Run
# =======================
if __name__ == "__main__":
    base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
    if os.path.exists(base_path):
        print(f"🔍 Checking for duplicate-named files in: {base_path}")
        find_duplicate_named_files(base_path)
    else:
        print("❌ The path does not exist.")
# Out:
# 🔍 Checking for duplicate-named files in: E:\DS_RAW_COMPLETE\DS_Structured
# ✅ Scanning complete.
# 📄 Actual duplicates logged in: E:\DS_RAW_COMPLETE\logs\5-actual_duplicates_after_deletion_log.txt
# 📄 Orphan-like duplicate names logged in: E:\DS_RAW_COMPLETE\logs\orphan_duplicate_named_log.txt

# %% [markdown]
# # Remove duplicate Files and Keep their original copies

# %%
import os
import re

def remove_any_parentheses(base_path):
    # Matches: optional space + (anything) 
    pattern = re.compile(r"\s*\([^)]*\)")

    for dirpath, _, filenames in os.walk(base_path):
        for filename in filenames:
            if pattern.search(filename):
                old_path = os.path.join(dirpath, filename)
                new_filename = pattern.sub('', filename).strip()
                new_path = os.path.join(dirpath, new_filename)

                if os.path.abspath(old_path) == os.path.abspath(new_path):
                    continue  # already clean, skip

                # If the clean file already exists — remove it to avoid duplicates
                if os.path.exists(new_path):
                    os.remove(new_path)
                    print(f"🗑️ Removed existing file to overwrite: {new_path}")

                os.rename(old_path, new_path)
                print(f"✅ Renamed: {old_path} → {new_path}")

    print("\n🎉 All matching files processed.")

# =======================
# Run
# =======================
if __name__ == "__main__":
    base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
    if os.path.exists(base_path):
        print(f"\n🔄 Renaming files in: {base_path}")
        remove_any_parentheses(base_path)
        print("\n✅ All done.")
    else:
        print("❌ The path does not exist.")
# Out:
# 🔄 Renaming files in: E:\DS_RAW_COMPLETE\DS_Structured
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_accelerometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\aliza\open_big_box\phone_linear_acceleration_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\throw_out\watch_magnetometer_uncalibrated_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf21m531\typing\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_left\watch_gyroscope_uncalibrated_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m529\fall_right\watch_magnetometer_uncalibrated_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m545\fall_backward\phone_linear_acceleration_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m501\clean_the_table\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m501\clean_the_table\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m501\clean_the_table\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m504\standing\phone_gyroscope_uncalibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m504\standing\phone_gyroscope_uncalibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m504\standing\phone_gyroscope_uncalibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e8.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e8(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\plugin\phone_magnetometer_e8.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\reading\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_accelerometer_calibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_accelerometer_calibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_accelerometer_calibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m515\sitting\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\eat_small_things\phone_gyroscope_uncalibrated_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\sitting_down_from_standing\watch_magnetometer_uncalibrated_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\slow_walk\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_accelerometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_accelerometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_accelerometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_interrupt_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_interrupt_gyroscope_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_interrupt_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_linear_acceleration_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\squatting\phone_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\standing\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\throw_out\phone_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\glass_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\glass_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\glass_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\typing\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_accelerometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\upstairs\glass_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m516\walking\glass_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\clean_the_table\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\watch_magnetometer_uncalibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\watch_magnetometer_uncalibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\jogging\watch_magnetometer_uncalibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\quick_walk\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer_uncalibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer_uncalibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m520\walking\watch_magnetometer_uncalibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\quick_walk\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\quick_walk\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\quick_walk\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\reading\phone_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\reading\phone_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m525\reading\phone_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\clean_the_table\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\quick_walk\watch_magnetometer_uncalibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\quick_walk\watch_magnetometer_uncalibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\quick_walk\watch_magnetometer_uncalibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\reading\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\standing\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m530\walking\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer_uncalibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer_uncalibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\walking\watch_magnetometer_uncalibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\jogging\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\laying\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\laying\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m537\laying\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_accelerometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_linear_acceleration.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_linear_acceleration(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_linear_acceleration.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\quick_walk\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m539\reading\watch_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\quick_walk\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\quick_walk\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\quick_walk\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_accelerometer_calibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_accelerometer_calibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_accelerometer_calibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_gravity.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_gravity(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m551\reading\phone_gravity.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\close_lid_by_rotation\phone_gravity_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\close_lid_by_rotation\phone_gravity_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\close_lid_by_rotation\phone_gravity_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward\phone_gyroscope_uncalibrated_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_calibrated_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\fall_backward_while_trying_to_sit_down\phone_accelerometer_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_gravity_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_gravity_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_gravity_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_magnetometer_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_magnetometer_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\watch_magnetometer_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_accelerometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_accelerometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_accelerometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gravity_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gravity_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gravity_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_uncalibrated_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_uncalibrated_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_gyroscope_uncalibrated_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0(3).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0(4).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0(3).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0(4).csv → E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\upstairs\watch_magnetometer_uncalibrated_e0.csv
# ...
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\squatting\watch_linear_acceleration_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\squatting\watch_linear_acceleration_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\squatting\watch_linear_acceleration_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_gyroscope_uncalibrated_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_laying\watch_linear_acceleration_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e5.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e6.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\glass_magnetometer_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e2.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e2(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e2.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e3.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e3(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e3.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e4.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e4(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\standing_up_from_sitting\phone_magnetometer_e4.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\talk_using_phone\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\talk_using_phone\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\talk_using_phone\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\throw_out\phone_gyroscope_e7.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\throw_out\phone_gyroscope_e7(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\throw_out\phone_gyroscope_e7.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\typing\phone_accelerometer_calibrated.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\typing\phone_accelerometer_calibrated(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\typing\phone_accelerometer_calibrated.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_interrupt_gyroscope_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_interrupt_gyroscope_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_interrupt_gyroscope_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e1.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e1(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_e1.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\upstairs\phone_magnetometer_uncalibrated_e0.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_interrupt_gyroscope.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer(2).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\phone_magnetometer.csv
# 🗑️ Removed existing file to overwrite: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\watch_accelerometer.csv
# ✅ Renamed: E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\watch_accelerometer(1).csv → E:\DS_RAW_COMPLETE\DS_Structured\msdsf23m015\walking\watch_accelerometer.csv
#
# 🎉 All matching files processed.
#
# ✅ All done.

# %% [markdown]
# # Remove unwanted and keep only prescribed ones

# %%
import os

def log_unwanted_files(base_path):
    allowed_keywords = ["gyroscope", "magnetometer", "accelerometer", "gravity", "linear_acceleration"]

    unwanted_keywords = [
        "phone_TMD4906_Proximity_Sensor",
        "phone_Step_Detector_Sensor",
        "phone_Screen_Orientation_Sensor",
        "phone_Tilt_Detector",
        "phone_Game_Rotation_Vector"
    ]

    log_path = r"E:\DS_RAW_COMPLETE\logs\filtered_files_log.txt"
    with open(log_path, 'w') as log:
        for dirpath, _, filenames in os.walk(base_path):
            for filename in filenames:
                file_path = os.path.join(dirpath, filename)

                if any(kw in filename for kw in unwanted_keywords):
                    log.write(f"{file_path}\n")
                    os.remove(file_path)
                    print(f"📝 Logged (unwanted): {file_path}")
                    continue

                if not any(kw in filename for kw in allowed_keywords):
                    log.write(f"{file_path}\n")
                    os.remove(file_path)
                    print(f"📝 Logged (not allowed): {file_path}")
                    continue

    print(f"\n📄 Log file saved to: {log_path}")
    print("✅ All files scanned.")

# =======================
# Run
# =======================
if __name__ == "__main__":
    base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
    if os.path.exists(base_path):
        print(f"\n🔍 Scanning files in: {base_path}")
        log_unwanted_files(base_path)
    else:
        print("❌ The path does not exist.")
# Out:
# 🔍 Scanning files in: E:\DS_RAW_COMPLETE\DS_Structured
# 📝 Logged (not allowed): E:\DS_RAW_COMPLETE\DS_Structured\filtered_files_log.txt
# 📝 Logged (not allowed): E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m527\fall_backward\phone_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m527\fall_backward\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m527\squatting\phone_TMD4906_Proximity_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\bcsf22m527\squatting\phone_TMD4906_Proximity_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\bending\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\clean_the_table\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_door\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\close_lid_by_rotation\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\drink_water\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\eat_small_things\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_backward\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Step_Detector_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_forward\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_left\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\fall_right\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\jogging\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\jogging\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying\phone_Screen_Orientation_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying\phone_Tilt_Detector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\laying_down_from_sitting\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_bag\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_big_box\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\open_door\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\pick_from_floor\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\plugin\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\quick_walk\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\quick_walk\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\reading\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting\phone_Tilt_Detector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\sitting_down_from_standing\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\slow_walk\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\slow_walk\phone_Screen_Orientation_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\slow_walk\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\squatting\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing\phone_Tilt_Detector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_laying\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\standing_up_from_sitting\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\talk_using_phone\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\throw_out\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\typing\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\walking\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\walking\phone_Screen_Orientation_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\guljanan\walking\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\bending\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\clean_the_table\phone_Game_Rotation_Vector.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\clean_the_table\phone_Screen_Orientation_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\clean_the_table\phone_Step_Detector_Sensor.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_door\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\close_lid_by_rotation\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\downstairs\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\drink_water\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\eat_small_things\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Screen_Orientation_Sensor_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward\phone_Tilt_Detector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_sit_down\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Screen_Orientation_Sensor_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Screen_Orientation_Sensor_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Tilt_Detector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_backward_while_trying_to_stand_up\phone_Tilt_Detector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_forward\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_forward\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\khalid\fall_forward\phone_Game_Rotation_Vector_e2.csv
# ...
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_backward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_forward_while_trying_to_sit_down\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_left\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\fall_right\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\laying_down_from_sitting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_bag\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_big_box\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\open_door\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\pick_from_floor\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\plugin\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\put_on_floor\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\sitting_down_from_standing\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\squatting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e5(1).csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e7(1).csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_laying\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\standing_up_from_sitting\phone_Game_Rotation_Vector_e7.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e0.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e1.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e2.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e3.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e4.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e5.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e6.csv
# 📝 Logged (unwanted): E:\DS_RAW_COMPLETE\DS_Structured\mahjabeen1\throw_out\phone_Game_Rotation_Vector_e7.csv
# 📄 Log file saved to: E:\DS_RAW_COMPLETE\logs\filtered_files_log.txt
# ✅ All files scanned.

# %% [markdown]
# # creates Log File

# %%
def prep_data(feat_filename):
    errors = []  # list of errors to return

    try:
        X = pd.read_csv(feat_filename, delimiter=",", decimal='.')
    except Exception as e:
        errors.append(f"Error reading {feat_filename}.")
        return errors
    if "(" in feat_filename:
        errors.append(f"Error parsing event number in {feat_filename}.")
    # If the file has 4 or more columns, use only the first 4 columns.
    if len(X.columns) >= 4:
        X = X.iloc[:, :4]
        X.columns = ['Timestamp', 'X', 'Y', 'Z']
    elif len(X.columns) >= 1:
        # You had this part commented — it does nothing
        # Possibly rename columns here if needed
        pass
    else:
        errors.append(f"Unexpected number of columns in {feat_filename}.")
    
    # (Your normal processing would continue here...)

    return errors

# %%
import os
import glob
import pandas as pd

error_log = []  # collect all errors here


base_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DS_AF"
subject_folders = glob.glob(os.path.join(base_path, "*"))

for subject in subject_folders:
    print("🚀 Processing subject ", subject);
    if not os.path.isdir(subject):
        continue

    activity_folders = glob.glob(os.path.join(subject, "*"))
    for activity_folder in activity_folders:
        if not os.path.isdir(activity_folder):
            continue

        event_files = glob.glob(os.path.join(activity_folder, "*.csv"))
        for f in event_files:
            errors = prep_data(f)
            if errors:
                error_log.extend(errors)

# Write all errors to a log file
with open(r"C:\Users\Malik Haider\Documents\HUMCARE\preprocessing_errors_log_af_after_clean.txt", "w") as log_file:
    for line in error_log:
        log_file.write(line + "\n")

print(f"✅ Finished. Logged {len(error_log)} issues to 'preprocessing_errors_log.txt'")
# Out:
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub1
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub10
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub11
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub12
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub13
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub14
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub15
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub16
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub17
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub18
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub19
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub2
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub20
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub21
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub22
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub23
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub24
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub25
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub26
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub27
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub28
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub29
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub3
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub30
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub31
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub32
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub33
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub34
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub35
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub36
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub38
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub39
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub4
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub40
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub41
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub42
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub43
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub44
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub45
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub47
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub48
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub49
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub5
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub50
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub51
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub52
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub53
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub55
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub56
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub57
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub58
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub59
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub6
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub60
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub61
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub62
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub63
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub64
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub65
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub66
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub67
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub68
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub69
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub7
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub70
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub71
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub72
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub74
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub75
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub76
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub78
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub79
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub8
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub80
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub81
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub82
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub83
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub84
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub85
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub86
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub87
# 🚀 Processing subject  C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub9
# ✅ Finished. Logged 0 issues to 'preprocessing_errors_log.txt'

# %% [markdown]
# # delete files with particular event no

# %%
import os
import re

def delete_files_with_same_event(log_path, dry_run=True):
    with open(log_path, 'r') as log_file:
        lines = log_file.readlines()

    event_files = set()

    # Extract unique (folder, event_suffix) pairs
    for line in lines:
        match = re.search(r'(C:.*?)(_e\d+\.csv)', line.strip(), re.IGNORECASE)
        if match:
            base_path = match.group(1)
            event_suffix = match.group(2)  # e.g., _e0.csv
            event_files.add((os.path.dirname(base_path), event_suffix))

    for folder, event_suffix in event_files:
        print(f"\n📂 Looking in: {folder}")
        pattern = re.compile(re.escape(event_suffix) + r'$', re.IGNORECASE)

        for fname in os.listdir(folder):
            if pattern.search(fname):
                fpath = os.path.join(folder, fname)
                if dry_run:
                    print(f"🔎 Would delete: {fpath}")
                else:
                    os.remove(fpath)
                    print(f"🗑️ Deleted: {fpath}")

    if dry_run:
        print("\n✅ Dry-run completed. No files were actually deleted.")
    else:
        print("\n✅ All matching event files removed.")

# ================================
# Run
# ================================
if __name__ == "__main__":
    log_file_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DS_AF_LOGS\missing_event_file.txt"
    dry_run = False  # set to False to actually delete

    if os.path.exists(log_file_path):
        delete_files_with_same_event(log_file_path, dry_run=dry_run)
    else:
        print("❌ Log file not found!")

# %% [markdown]
# # Delete files without event number

# %%
import os
import re

def delete_files_without_event(base_path, dry_run=True):
    """
    Deletes files that do NOT contain _e<number> in their name
    """
    event_pattern = re.compile(r'_e\d+', re.IGNORECASE)

    for dirpath, _, filenames in os.walk(base_path):
        for fname in filenames:
            if not event_pattern.search(fname):
                fpath = os.path.join(dirpath, fname)
                if dry_run:
                    print(f"🔎 Would delete (no event): {fpath}")
                else:
                    os.remove(fpath)
                    print(f"🗑️ Deleted (no event): {fpath}")

    if dry_run:
        print("\n✅ Dry-run completed. No files were actually deleted.")
    else:
        print("\n✅ All files without _e<number> have been removed.")

# ================================
# Run
# ================================
if __name__ == "__main__":
    base_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DS_AF"
    dry_run = False  # set to False to actually delete

    if os.path.exists(base_path):
        delete_files_without_event(base_path, dry_run=dry_run)
    else:
        print("❌ Base path does not exist!")
# Out:
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub10\standing\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub10\standing\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub10\standing\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub12\downstairs\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub12\downstairs\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub12\downstairs\phone_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub26\clean_the_table\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub26\clean_the_table\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub26\clean_the_table\phone_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub28\reading\watch_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub31\walking\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37\reading\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37\reading\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37\reading\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37\reading\watch_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub37\reading\watch_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\downstairs\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\downstairs\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\downstairs\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\sitting\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\upstairs\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\upstairs\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub46\upstairs\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\watch_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\watch_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\open_bag\watch_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\quick_walk\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\quick_walk\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub54\quick_walk\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub56\reading\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub56\reading\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub56\reading\phone_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub60\slow_walk\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub60\slow_walk\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub60\slow_walk\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub61\upstairs\watch_accelerometer_1.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub61\upstairs\watch_gyroscope_1.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub61\upstairs\watch_magnetometer_1.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub63\talk_using_phone\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73\reading\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73\reading\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73\walking\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73\walking\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub73\walking\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub76\typing\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub76\typing\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub76\typing\watch_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\phone_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\phone_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\phone_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\watch_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\watch_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub77\standing\watch_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub78\reading\phone_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub79\jogging\glass_accelerometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub79\jogging\glass_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub79\jogging\glass_magnetometer.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub84\walking\watch_gyroscope.csv
# 🗑️ Deleted (no event): C:\Users\Malik Haider\Documents\HUMCARE\DS_AF\sub84\walking\watch_magnetometer.csv
#
# ✅ All files without _e<number> have been removed.

# %% [markdown]
# # Separate the Fall data from ADL

# %%
import os
import shutil

# List of exact fall activity folder names to match
fall_activities = [
    "fall_backward",
    "fall_backward_when_trying_to_sit_down",
    "fall_backward_while_trying_to_sit_down",
    "fall_backward_when_trying_to_stand_up",
    "fall_backward_while_trying_to_stand_up",
    "fall_forward",
    "fall_forward_when_trying_to_sit_down",
    "fall_forward_while_trying_to_sit_down",
    "fall_forward_when_trying_to_stand_up",
    "fall_forward_while_trying_to_stand_up",
    "fall_left",
    "fall_right"
]

def copy_and_remove_fall_folders(src_root, dest_root):
    if not os.path.exists(src_root):
        print("❌ Source path does not exist.")
        return

    # Create destination if it doesn't exist
    if not os.path.exists(dest_root):
        os.makedirs(dest_root)

    # Iterate through each user folder
    for user_folder in os.listdir(src_root):
        user_path = os.path.join(src_root, user_folder)

        if os.path.isdir(user_path):
            # Create user folder in destination
            dest_user_path = os.path.join(dest_root, user_folder)
            os.makedirs(dest_user_path, exist_ok=True)

            # List all subfolders (activities) inside user folder
            for activity_folder in os.listdir(user_path):
                activity_path = os.path.join(user_path, activity_folder)

                if os.path.isdir(activity_path) and activity_folder in fall_activities:
                    dest_activity_path = os.path.join(dest_user_path, activity_folder)
                    print(f"📁 Copying {activity_path} to {dest_activity_path}")
                    try:
                        shutil.copytree(activity_path, dest_activity_path, dirs_exist_ok=True)
                        shutil.rmtree(activity_path)  # ✅ Delete after copy
                        print(f"🗑️ Deleted source folder: {activity_path}")
                    except Exception as e:
                        print(f"⚠️ Error copying/deleting {activity_path}: {e}")

    print("✅ Copy and delete operation completed.")

# Main execution
if __name__ == "__main__":
    src = r"C:\Users\hp\Downloads\DS_AF - Copy - Copy\DS_AF"
    dst = r"C:\Users\hp\Downloads\DS_AF - Copy - Copy\DS_FALL"
    copy_and_remove_fall_folders(src, dst)

# %% [markdown]
# # remove empty folder and rename them

# %%
import os
import shutil

def delete_empty_and_rename(base_path):
    """
    Delete empty folders and rename remaining subfolders sequentially as sub1, sub2, …
    """
    # Step 1: Delete empty folders
    for root, dirs, _ in os.walk(base_path, topdown=False):
        for d in dirs:
            folder_path = os.path.join(root, d)
            if not os.listdir(folder_path):
                os.rmdir(folder_path)
                print(f"🗑️ Deleted empty folder: {folder_path}")

    # Step 2: Get remaining folders
    remaining = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
    remaining.sort()  # optional: sort alphabetically

    # Step 3: Rename them to sub1, sub2, …
    for idx, folder in enumerate(remaining, 1):
        old_path = os.path.join(base_path, folder)
        new_name = f"sub{idx}"
        new_path = os.path.join(base_path, new_name)

        if old_path != new_path:
            if os.path.exists(new_path):
                print(f"⚠️ Cannot rename {old_path} to {new_path} (already exists!)")
            else:
                os.rename(old_path, new_path)
                print(f"✅ Renamed: {old_path} → {new_path}")

    print("\n🎉 Done: Empty folders deleted and remaining renamed sequentially.")

# ===================================
# Run
# ===================================
if __name__ == "__main__":
    base_path = r"C:\Users\hp\Downloads\DS_AF - Copy - Copy\DS_FALL"

    if os.path.exists(base_path):
        delete_empty_and_rename(base_path)
    else:
        print("❌ Base path does not exist!")

# %%
import os

def delete_empty_and_rename(base_path):
    """
    Delete empty folders and rename remaining subfolders sequentially as sub1, sub2, …
    """
    # Step 1: Delete empty folders
    for root, dirs, _ in os.walk(base_path, topdown=False):
        for d in dirs:
            folder_path = os.path.join(root, d)
            if not os.listdir(folder_path):
                os.rmdir(folder_path)
                print(f"🗑️ Deleted empty folder: {folder_path}")

    # Step 2: Get remaining folders
    remaining = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
    remaining.sort()  # sort alphabetically

    # Step 3: Rename to temporary names to avoid conflicts
    temp_names = []
    for idx, folder in enumerate(remaining):
        old_path = os.path.join(base_path, folder)
        tmp_name = f"tmp_rename_{idx}"
        tmp_path = os.path.join(base_path, tmp_name)
        os.rename(old_path, tmp_path)
        temp_names.append(tmp_name)
        print(f"🔄 Renamed to temp: {folder} → {tmp_name}")

    # Step 4: Rename temp folders to final sequential names
    for idx, tmp_name in enumerate(temp_names, 1):
        tmp_path = os.path.join(base_path, tmp_name)
        final_name = f"sub{idx}"
        final_path = os.path.join(base_path, final_name)
        os.rename(tmp_path, final_path)
        print(f"✅ Renamed: {tmp_name} → {final_name}")

    print("\n🎉 Done: Empty folders deleted and remaining renamed sequentially.")

# ===================================
# Run
# ===================================
if __name__ == "__main__":
    base_path = r"C:\Users\hp\Downloads\DS_AF - Copy - Copy\DS_AF"

    if os.path.exists(base_path):
        delete_empty_and_rename(base_path)
    else:
        print("❌ Base path does not exist!")
# Out:
# 🔄 Renamed to temp: sub1 → tmp_rename_0
# 🔄 Renamed to temp: sub10 → tmp_rename_1
# 🔄 Renamed to temp: sub11 → tmp_rename_2
# 🔄 Renamed to temp: sub12 → tmp_rename_3
# 🔄 Renamed to temp: sub13 → tmp_rename_4
# 🔄 Renamed to temp: sub14 → tmp_rename_5
# 🔄 Renamed to temp: sub15 → tmp_rename_6
# 🔄 Renamed to temp: sub16 → tmp_rename_7
# 🔄 Renamed to temp: sub17 → tmp_rename_8
# 🔄 Renamed to temp: sub18 → tmp_rename_9
# 🔄 Renamed to temp: sub19 → tmp_rename_10
# 🔄 Renamed to temp: sub2 → tmp_rename_11
# 🔄 Renamed to temp: sub20 → tmp_rename_12
# 🔄 Renamed to temp: sub21 → tmp_rename_13
# 🔄 Renamed to temp: sub22 → tmp_rename_14
# 🔄 Renamed to temp: sub23 → tmp_rename_15
# 🔄 Renamed to temp: sub24 → tmp_rename_16
# 🔄 Renamed to temp: sub25 → tmp_rename_17
# 🔄 Renamed to temp: sub26 → tmp_rename_18
# 🔄 Renamed to temp: sub27 → tmp_rename_19
# 🔄 Renamed to temp: sub28 → tmp_rename_20
# 🔄 Renamed to temp: sub29 → tmp_rename_21
# 🔄 Renamed to temp: sub3 → tmp_rename_22
# 🔄 Renamed to temp: sub30 → tmp_rename_23
# 🔄 Renamed to temp: sub31 → tmp_rename_24
# 🔄 Renamed to temp: sub32 → tmp_rename_25
# 🔄 Renamed to temp: sub33 → tmp_rename_26
# 🔄 Renamed to temp: sub34 → tmp_rename_27
# 🔄 Renamed to temp: sub35 → tmp_rename_28
# 🔄 Renamed to temp: sub36 → tmp_rename_29
# 🔄 Renamed to temp: sub37 → tmp_rename_30
# 🔄 Renamed to temp: sub38 → tmp_rename_31
# 🔄 Renamed to temp: sub39 → tmp_rename_32
# 🔄 Renamed to temp: sub4 → tmp_rename_33
# 🔄 Renamed to temp: sub40 → tmp_rename_34
# 🔄 Renamed to temp: sub41 → tmp_rename_35
# 🔄 Renamed to temp: sub42 → tmp_rename_36
# 🔄 Renamed to temp: sub43 → tmp_rename_37
# 🔄 Renamed to temp: sub44 → tmp_rename_38
# 🔄 Renamed to temp: sub45 → tmp_rename_39
# 🔄 Renamed to temp: sub46 → tmp_rename_40
# 🔄 Renamed to temp: sub47 → tmp_rename_41
# 🔄 Renamed to temp: sub48 → tmp_rename_42
# 🔄 Renamed to temp: sub49 → tmp_rename_43
# 🔄 Renamed to temp: sub5 → tmp_rename_44
# 🔄 Renamed to temp: sub50 → tmp_rename_45
# 🔄 Renamed to temp: sub51 → tmp_rename_46
# 🔄 Renamed to temp: sub52 → tmp_rename_47
# 🔄 Renamed to temp: sub53 → tmp_rename_48
# 🔄 Renamed to temp: sub54 → tmp_rename_49
# 🔄 Renamed to temp: sub55 → tmp_rename_50
# 🔄 Renamed to temp: sub56 → tmp_rename_51
# 🔄 Renamed to temp: sub57 → tmp_rename_52
# 🔄 Renamed to temp: sub58 → tmp_rename_53
# 🔄 Renamed to temp: sub59 → tmp_rename_54
# 🔄 Renamed to temp: sub6 → tmp_rename_55
# 🔄 Renamed to temp: sub60 → tmp_rename_56
# 🔄 Renamed to temp: sub61 → tmp_rename_57
# 🔄 Renamed to temp: sub62 → tmp_rename_58
# 🔄 Renamed to temp: sub63 → tmp_rename_59
# 🔄 Renamed to temp: sub64 → tmp_rename_60
# 🔄 Renamed to temp: sub65 → tmp_rename_61
# 🔄 Renamed to temp: sub66 → tmp_rename_62
# 🔄 Renamed to temp: sub67 → tmp_rename_63
# 🔄 Renamed to temp: sub68 → tmp_rename_64
# 🔄 Renamed to temp: sub69 → tmp_rename_65
# 🔄 Renamed to temp: sub7 → tmp_rename_66
# 🔄 Renamed to temp: sub70 → tmp_rename_67
# 🔄 Renamed to temp: sub71 → tmp_rename_68
# 🔄 Renamed to temp: sub72 → tmp_rename_69
# 🔄 Renamed to temp: sub73 → tmp_rename_70
# 🔄 Renamed to temp: sub74 → tmp_rename_71
# 🔄 Renamed to temp: sub75 → tmp_rename_72
# 🔄 Renamed to temp: sub76 → tmp_rename_73
# 🔄 Renamed to temp: sub77 → tmp_rename_74
# 🔄 Renamed to temp: sub78 → tmp_rename_75
# 🔄 Renamed to temp: sub79 → tmp_rename_76
# 🔄 Renamed to temp: sub8 → tmp_rename_77
# 🔄 Renamed to temp: sub80 → tmp_rename_78
# 🔄 Renamed to temp: sub81 → tmp_rename_79
# 🔄 Renamed to temp: sub9 → tmp_rename_80
# ✅ Renamed: tmp_rename_0 → sub1
# ✅ Renamed: tmp_rename_1 → sub2
# ✅ Renamed: tmp_rename_2 → sub3
# ✅ Renamed: tmp_rename_3 → sub4
# ✅ Renamed: tmp_rename_4 → sub5
# ✅ Renamed: tmp_rename_5 → sub6
# ✅ Renamed: tmp_rename_6 → sub7
# ✅ Renamed: tmp_rename_7 → sub8
# ✅ Renamed: tmp_rename_8 → sub9
# ✅ Renamed: tmp_rename_9 → sub10
# ✅ Renamed: tmp_rename_10 → sub11
# ✅ Renamed: tmp_rename_11 → sub12
# ✅ Renamed: tmp_rename_12 → sub13
# ✅ Renamed: tmp_rename_13 → sub14
# ✅ Renamed: tmp_rename_14 → sub15
# ✅ Renamed: tmp_rename_15 → sub16
# ✅ Renamed: tmp_rename_16 → sub17
# ✅ Renamed: tmp_rename_17 → sub18
# ✅ Renamed: tmp_rename_18 → sub19
# ✅ Renamed: tmp_rename_19 → sub20
# ✅ Renamed: tmp_rename_20 → sub21
# ✅ Renamed: tmp_rename_21 → sub22
# ✅ Renamed: tmp_rename_22 → sub23
# ✅ Renamed: tmp_rename_23 → sub24
# ✅ Renamed: tmp_rename_24 → sub25
# ✅ Renamed: tmp_rename_25 → sub26
# ✅ Renamed: tmp_rename_26 → sub27
# ✅ Renamed: tmp_rename_27 → sub28
# ✅ Renamed: tmp_rename_28 → sub29
# ✅ Renamed: tmp_rename_29 → sub30
# ✅ Renamed: tmp_rename_30 → sub31
# ✅ Renamed: tmp_rename_31 → sub32
# ✅ Renamed: tmp_rename_32 → sub33
# ✅ Renamed: tmp_rename_33 → sub34
# ✅ Renamed: tmp_rename_34 → sub35
# ✅ Renamed: tmp_rename_35 → sub36
# ✅ Renamed: tmp_rename_36 → sub37
# ✅ Renamed: tmp_rename_37 → sub38
# ✅ Renamed: tmp_rename_38 → sub39
# ✅ Renamed: tmp_rename_39 → sub40
# ✅ Renamed: tmp_rename_40 → sub41
# ✅ Renamed: tmp_rename_41 → sub42
# ✅ Renamed: tmp_rename_42 → sub43
# ✅ Renamed: tmp_rename_43 → sub44
# ✅ Renamed: tmp_rename_44 → sub45
# ✅ Renamed: tmp_rename_45 → sub46
# ✅ Renamed: tmp_rename_46 → sub47
# ✅ Renamed: tmp_rename_47 → sub48
# ✅ Renamed: tmp_rename_48 → sub49
# ✅ Renamed: tmp_rename_49 → sub50
# ✅ Renamed: tmp_rename_50 → sub51
# ✅ Renamed: tmp_rename_51 → sub52
# ✅ Renamed: tmp_rename_52 → sub53
# ✅ Renamed: tmp_rename_53 → sub54
# ✅ Renamed: tmp_rename_54 → sub55
# ✅ Renamed: tmp_rename_55 → sub56
# ✅ Renamed: tmp_rename_56 → sub57
# ✅ Renamed: tmp_rename_57 → sub58
# ✅ Renamed: tmp_rename_58 → sub59
# ✅ Renamed: tmp_rename_59 → sub60
# ✅ Renamed: tmp_rename_60 → sub61
# ✅ Renamed: tmp_rename_61 → sub62
# ✅ Renamed: tmp_rename_62 → sub63
# ✅ Renamed: tmp_rename_63 → sub64
# ✅ Renamed: tmp_rename_64 → sub65
# ✅ Renamed: tmp_rename_65 → sub66
# ✅ Renamed: tmp_rename_66 → sub67
# ✅ Renamed: tmp_rename_67 → sub68
# ✅ Renamed: tmp_rename_68 → sub69
# ✅ Renamed: tmp_rename_69 → sub70
# ✅ Renamed: tmp_rename_70 → sub71
# ✅ Renamed: tmp_rename_71 → sub72
# ✅ Renamed: tmp_rename_72 → sub73
# ✅ Renamed: tmp_rename_73 → sub74
# ✅ Renamed: tmp_rename_74 → sub75
# ✅ Renamed: tmp_rename_75 → sub76
# ✅ Renamed: tmp_rename_76 → sub77
# ✅ Renamed: tmp_rename_77 → sub78
# ✅ Renamed: tmp_rename_78 → sub79
# ✅ Renamed: tmp_rename_79 → sub80
# ✅ Renamed: tmp_rename_80 → sub81
#
# 🎉 Done: Empty folders deleted and remaining renamed sequentially.

# %% [markdown]
# # Verify The Dataset for 9 sensors for each event

# %%
import os,glob,re
from collections import defaultdict

base_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DS_AF"
log_path = r'C:\Users\Malik Haider\Documents\HUMCARE\DS_AF_LOGS\missing_event_file.txt'
sensor9 = [
    'glass_accelerometer','glass_gyroscope','glass_magnetometer',
      'phone_accelerometer','phone_gyroscope','phone_magnetometer',
      'watch_accelerometer','watch_gyroscope','watch_magnetometer'
]
sensor6 = [ 
    'phone_accelerometer', 'phone_gyroscope', 'phone_magnetometer',
    'watch_accelerometer', 'watch_gyroscope', 'watch_magnetometer'
]
sixSensorActivities = {
    'fall_forward','fall_right','fall_backward','fall_left',
    'fall_forward_when_trying_to_sit_down','fall_backward_while_trying_to_sit_down',
    'fall_forward_while_trying_to_stand_up','fall_backward_while_trying_to_stand_up'
}

pattern = re.compile(r'^(glass|phone|watch)_(accelerometer|gyroscope|magnetometer)_e(\d+)\.csv$', re.I)

open(log_path,'w').close()

for subj in glob.glob(os.path.join(base_path, '*')):
    if not os.path.isdir(subj): continue
    for act in glob.glob(os.path.join(subj, '*')):
        if not os.path.isdir(act): continue
        req = sensor6 if os.path.basename(act) in sixSensorActivities else sensor9
        evs = defaultdict(set)
        fm = {}
        for fp in glob.glob(os.path.join(act, '*.csv')):
            m = pattern.match(os.path.basename(fp))
            if m:
                k = f"{m.group(1).lower()}_{m.group(2).lower()}"
                e = int(m.group(3))
                evs[e].add(k)
                fm[(e, k)] = fp
        with open(log_path, 'a') as log:
            for e, seen in sorted(evs.items()):
                if len(seen) < len(req):
                    for k in seen:
                        log.write(f"{fm[(e, k)]}\n")

# %% [markdown]
# # Get Folders with Imbalance events

# %%
import os,glob

base_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DS_AF"
six = {
    'fall_forward','fall_right','fall_backward','fall_left',
    'fall_forward_when_trying_to_sit_down','fall_backward_while_trying_to_sit_down',
    'fall_forward_while_trying_to_stand_up','fall_backward_while_trying_to_stand_up'
}

for subj in glob.glob(os.path.join(base_path,'*')):
    if not os.path.isdir(subj): continue
    for act in glob.glob(os.path.join(subj,'*')):
        if not os.path.isdir(act): continue
        req = 6 if os.path.basename(act) in six else 9
        cnt = len(glob.glob(os.path.join(act,'*.csv')))
        if cnt % req != 0:
            print(act, cnt)
print("Complete")
# Out:
# Complete

# %% [markdown]
# # Get DS stats

# %%
import os
import glob
from collections import defaultdict

# Define sensor list
sensor_order = [
    'glass_accelerometer',
    'glass_gyroscope',
    'glass_magnetometer',
    'phone_accelerometer_calibrated',
    'phone_accelerometer',
    'phone_gravity',
    'phone_linear_acceleration',
    'phone_gyroscope_uncalibrated',
    'phone_gyroscope',
    'phone_magnetometer_uncalibrated',
    'phone_magnetometer',
    'phone_interrupt_gyroscope',
    'watch_accelerometer',
    'watch_gyroscope_uncalibrated',
    'watch_linear_acceleration',
    'watch_gyroscope',
    'watch_magnetometer_uncalibrated',
    'watch_magnetometer',
    'watch_gravity',
]

# Initialize counters
sensor_file_counts = defaultdict(int)
total_event_instances = 0

# Path to dataset
base_path = r"C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data"

# Traverse all subject folders
subject_folders = glob.glob(os.path.join(base_path, "*"))

for subject in subject_folders:
    if not os.path.isdir(subject):
        continue
    activity_folders = glob.glob(os.path.join(subject, "*"))
    
    for activity_folder in activity_folders:
        if not os.path.isdir(activity_folder):
            continue

        event_files = glob.glob(os.path.join(activity_folder, "*.csv"))
        event_dict = defaultdict(dict)

        for f in event_files:
            filename = os.path.basename(f).lower()
            if "_e" in filename:
                try:
                    event_num = int(filename.split("_e")[1].split(".")[0])
                except Exception:
                    continue

                for sensor in sensor_order:
                    if sensor in filename:
                        sensor_file_counts[sensor] += 1
                        event_dict[event_num][sensor] = f
                        break
#         if(sensor_file_counts["watch_accelerometer"] != sensor_file_counts["phone_accelerometer"] or sensor_file_counts["watch_gyroscope"] != sensor_file_counts["watch_accelerometer"]):
            
#             print(sensor_file_counts["watch_accelerometer"])
#             print(sensor_file_counts["phone_accelerometer"])
#             print(activity_folder)
        # Count events where at least one sensor file exists
        total_event_instances += len(event_dict)
   
    
# Display Results
print("📊 Sensor File Counts:")
for sensor in sensor_order:
    print(f"  {sensor:25s}: {sensor_file_counts[sensor]} files")

print(f"\n📦 Total Distinct Event Instances: {total_event_instances}")
# Out:
# 📊 Sensor File Counts:
#   glass_accelerometer      : 639 files
#   glass_gyroscope          : 639 files
#   glass_magnetometer       : 639 files
#   phone_accelerometer_calibrated: 910 files
#   phone_accelerometer      : 910 files
#   phone_gravity            : 396 files
#   phone_linear_acceleration: 910 files
#   phone_gyroscope_uncalibrated: 910 files
#   phone_gyroscope          : 903 files
#   phone_magnetometer_uncalibrated: 903 files
#   phone_magnetometer       : 910 files
#   phone_interrupt_gyroscope: 790 files
#   watch_accelerometer      : 908 files
#   watch_gyroscope_uncalibrated: 908 files
#   watch_linear_acceleration: 908 files
#   watch_gyroscope          : 908 files
#   watch_magnetometer_uncalibrated: 907 files
#   watch_magnetometer       : 907 files
#   watch_gravity            : 286 files
#
# 📦 Total Distinct Event Instances: 911

# %% [markdown]
# # Generate log file for empty folders

# %%
import os

base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
log_path = r'E:\DS_RAW_COMPLETE\logs\empty_folders.txt'

def is_empty(dir_path):
    return not any(os.scandir(dir_path))

open(log_path, 'w').close()

for subject in os.listdir(base_path):
    subj_path = os.path.join(base_path, subject)
    if os.path.isdir(subj_path):
        if is_empty(subj_path):
            with open(log_path, 'a') as log:
                log.write(f"{subj_path}\n")
        else:
            for activity in os.listdir(subj_path):
                act_path = os.path.join(subj_path, activity)
                if os.path.isdir(act_path) and is_empty(act_path):
                    with open(log_path, 'a') as log:
                        log.write(f"{act_path}\n")
                    os.rmdir(act_path)

# %% [markdown]
# # Generate log file with less number of required samples for 4 seconds

# %%
import os
import glob
import pandas as pd
from collections import defaultdict

# ========== Configuration ==========
base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
log_dir =  r"E:\DS_RAW_COMPLETE\logs\7-less_sample_logs"
os.makedirs(log_dir, exist_ok=True)

# ========== Minimum expected samples ==========
expected_samples = {
    'glass_accelerometer':  20,
    'glass_gyroscope':      20,
    'glass_magnetometer':   20,
    'phone_accelerometer_calibrated' : 400,
    'phone_accelerometer': 2000,
    'phone_gravity': 800,
    'phone_linear_acceleration': 400,
    'phone_gyroscope_uncalibrated': 2000,
    'phone_gyroscope':     2000,
    'phone_magnetometer_uncalibrated': 400,
    'phone_magnetometer':  400,
    'phone_interrupt_gyroscope': 100,
    'watch_accelerometer': 400,
    'watch_gyroscope_uncalibrated': 800,
    'watch_linear_acceleration': 400,
    'watch_gyroscope':     400,
    'watch_magnetometer_uncalibrated': 400,
    'watch_magnetometer':  400,
    'watch_gravity': 400,
}

# ========== Detect sensors from filenames ==========
sensor_keys = list(expected_samples.keys())

# ========== Track undersampled files ==========
lengths = defaultdict(dict)

# ========== Processing ==========
for subj in glob.glob(os.path.join(base_path, '*')):
    if not os.path.isdir(subj): continue
    for act in glob.glob(os.path.join(subj, '*')):
        if not os.path.isdir(act): continue
        for fp in glob.glob(os.path.join(act, '*.csv')):
            fname = os.path.basename(fp).lower()

            # Filter only files with '_e' in name
            if "_e" not in fname:
                continue

            sensor = next((s for s in sensor_keys if s in fname), None)
            if not sensor:
                continue

            try:
                df = pd.read_csv(fp)
                cnt = len(df)
            except Exception as e:
                print(f"❌ Error reading: {fp} — {e}")
                continue

            lengths[sensor][fp] = cnt

            if cnt < expected_samples[sensor]:
                log_file = os.path.join(log_dir, f"{sensor}_undersample_log.txt")
                with open(log_file, 'a', encoding='utf-8') as log:
                    log.write(f"{fp}: {cnt} rows (expected ≥ {expected_samples[sensor]})\n")

print("✅ All undersampled logs written per sensor.")
# Out:
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_forward_while_trying_to_sit_down\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_accelerometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\fall_left\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\pick_from_floor\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\plugin\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_accelerometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\sitting_down_from_standing\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m535\squatting\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m552\throw_out\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_accelerometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_gyroscope_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_linear_acceleration_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_magnetometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\fall_backward_while_trying_to_stand_up\watch_magnetometer_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\open_bag\phone_interrupt_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\open_bag\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bcsf24m554\plugin\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_accelerometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\eat_small_things\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_bag\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_big_box\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_big_box\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_big_box\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\open_big_box\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m502\pick_from_floor\phone_interrupt_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m507\open_big_box\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\fall_backward_while_trying_to_stand_up\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\plugin\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\put_on_floor\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\put_on_floor\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\put_on_floor\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m516\put_on_floor\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\bending\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\bending\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\bending\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\bending\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\close_lid_by_rotation\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\laying_down_from_sitting\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m530\open_big_box\phone_interrupt_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\drink_water\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\drink_water\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\drink_water\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\eat_small_things\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_accelerometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\open_door\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m533\plugin\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\bending\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\bending\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\bending\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\bending\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\close_lid_by_rotation\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\fall_right\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\open_big_box\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\plugin\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_accelerometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_gyroscope_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_linear_acceleration_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_magnetometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m536\throw_out\watch_magnetometer_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\bending\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\bending\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\bending\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\bending\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\bending\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_accelerometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\downstairs\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\fall_forward_while_trying_to_sit_down\watch_accelerometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\fall_forward_while_trying_to_sit_down\watch_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\fall_forward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\open_bag\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\standing_up_from_sitting\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\standing_up_from_sitting\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_accelerometer_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_gyroscope_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_gyroscope_uncalibrated_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_linear_acceleration_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_magnetometer_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m541\upstairs\watch_magnetometer_uncalibrated_e8.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_backward\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_left\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\fall_left\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\open_door\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\open_door\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m542\standing_up_from_laying\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\bending\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\bending\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\bending\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_linear_acceleration_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_magnetometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_backward\watch_magnetometer_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_forward_while_trying_to_sit_down\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_left\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_left\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_left\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_left\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\fall_left\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\throw_out\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bitf21m549\throw_out\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\downstairs\phone_interrupt_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\drink_water\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\eat_small_things\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\eat_small_things\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\eat_small_things\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m509\eat_small_things\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\phone_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\phone_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\phone_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\phone_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\fall_forward_while_trying_to_stand_up\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\laying_down_from_sitting\glass_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\laying_down_from_sitting\glass_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\laying_down_from_sitting\glass_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m523\upstairs\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\close_door\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\close_door\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\close_door\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\close_door\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\close_door\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\plugin\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\sitting_down_from_standing\glass_accelerometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\sitting_down_from_standing\glass_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m535\sitting_down_from_standing\glass_magnetometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\open_bag\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\open_bag\phone_interrupt_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\open_bag\phone_interrupt_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\plugin\phone_interrupt_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_accelerometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m541\throw_out\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\fall_forward_while_trying_to_stand_up\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\laying_down_from_sitting\phone_accelerometer_calibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\laying_down_from_sitting\phone_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\laying_down_from_sitting\phone_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\laying_down_from_sitting\phone_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_big_box\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\open_door\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\plugin\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m542\standing_up_from_laying\phone_interrupt_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_accelerometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_accelerometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_gyroscope_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_linear_acceleration_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_magnetometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\bending\watch_magnetometer_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_backward_while_trying_to_sit_down\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_backward_while_trying_to_sit_down\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_backward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_backward_while_trying_to_sit_down\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_forward\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_forward\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_forward\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_forward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\fall_forward_while_trying_to_sit_down\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\open_big_box\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\pick_from_floor\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\pick_from_floor\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\pick_from_floor\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m548\pick_from_floor\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\bending\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\bending\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\bending\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\bending\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\drink_water\phone_interrupt_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_backward\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\fall_forward\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_bag\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\open_big_box\phone_interrupt_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\bsef21m558\standing_up_from_laying\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\guljanan\put_on_floor\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_backward_while_trying_to_sit_down\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_backward_while_trying_to_sit_down\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_backward_while_trying_to_sit_down\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_backward_while_trying_to_sit_down\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_backward_while_trying_to_sit_down\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_accelerometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\fall_forward_while_trying_to_sit_down\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\open_big_box\phone_interrupt_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\open_door\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\open_door\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\open_door\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\hannan\open_door\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ...
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\open_big_box\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\standing_up_from_laying\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\throw_out\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\throw_out\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\throw_out\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\raahim\throw_out\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_accelerometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_gyroscope_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_linear_acceleration_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_magnetometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_backward_while_trying_to_stand_up\watch_magnetometer_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_forward\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_accelerometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_gyroscope_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_linear_acceleration_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_magnetometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\fall_right\watch_magnetometer_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\laying_down_from_sitting\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\open_door\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\open_door\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\open_door\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\open_door\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\open_door\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\phone_interrupt_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\watch_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\watch_gyroscope_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\watch_linear_acceleration_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\watch_magnetometer_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\plugin\watch_magnetometer_uncalibrated_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\throw_out\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\throw_out\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\throw_out\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\rehanasif\throw_out\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\bending\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\close_lid_by_rotation\phone_interrupt_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\downstairs\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\downstairs\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\downstairs\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\downstairs\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\downstairs\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\fall_forward\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\fall_forward\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_bag\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_accelerometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_accelerometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_gyroscope_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_gyroscope_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_gyroscope_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_linear_acceleration_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_linear_acceleration_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_magnetometer_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_magnetometer_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_magnetometer_uncalibrated_e0.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_big_box\watch_magnetometer_uncalibrated_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_accelerometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_gyroscope_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_gyroscope_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_linear_acceleration_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_magnetometer_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\open_door\watch_magnetometer_uncalibrated_e7.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\put_on_floor\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\put_on_floor\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\squatting\watch_accelerometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\squatting\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\squatting\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\throw_out\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\shahbaz\throw_out\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\drink_water\watch_gyroscope_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\laying_down_from_sitting\watch_gyroscope_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\laying_down_from_sitting\watch_gyroscope_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\laying_down_from_sitting\watch_linear_acceleration_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\laying_down_from_sitting\watch_magnetometer_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\laying_down_from_sitting\watch_magnetometer_uncalibrated_e2.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\open_big_box\watch_gyroscope_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\open_big_box\watch_gyroscope_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\open_big_box\watch_linear_acceleration_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\open_big_box\watch_magnetometer_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\open_big_box\watch_magnetometer_uncalibrated_e6.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_accelerometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_gyroscope_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_gyroscope_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_linear_acceleration_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_magnetometer_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\pick_from_floor\watch_magnetometer_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\plugin\phone_interrupt_gyroscope_e1.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\plugin\phone_interrupt_gyroscope_e3.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_accelerometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_gyroscope_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_gyroscope_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_linear_acceleration_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_magnetometer_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\put_on_floor\watch_magnetometer_uncalibrated_e5.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\throw_out\watch_gyroscope_uncalibrated_e4.csv — No columns to parse from file
# ❌ Error reading: E:\DS_RAW_COMPLETE\DS_Structured\tayyab\upstairs\watch_magnetometer_e5.csv — No columns to parse from file
# ✅ All undersampled logs written per sensor.

# %%
# print(lengths['glass_accelerometer'].values())
sum = 0
count = 0
for val in lengths['phone_accelerometer'].values():
    sum += val
    if(val < 100):
        count+=1
        

print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 sum = 0
#       3 count = 0
# ----> 4 for val in lengths['phone_accelerometer'].values():
#       5     sum += val
#       6     if(val < 100):
#
# NameError: name 'lengths' is not defined

# %% [markdown]
# # Generate logs for empty and invalid and no rows files

# %%
import os
import pandas as pd

def log_empty_csvs(base_path):
    empty_log = r"E:\DS_RAW_COMPLETE\logs\6-empty_csv_files_log.txt"
    corrupt_log = r"E:\DS_RAW_COMPLETE\logs\6-corrupt_csv_files_log.txt"
    no_rows_log = r"E:\DS_RAW_COMPLETE\logs\6-no_rows_csv_files_log.txt"

    # clear or create
    open(empty_log, 'w').close()
    open(corrupt_log, 'w').close()
    open(no_rows_log, 'w').close()

    for dirpath, _, filenames in os.walk(base_path):
        for fname in filenames:
            if not fname.lower().endswith('.csv'):
                continue
            full_path = os.path.join(dirpath, fname)

            # size zero
            try:
                if os.path.getsize(full_path) == 0:
                    with open(empty_log, 'a') as f:
                        f.write(f"{full_path}\n")
                    continue
            except OSError:
                # cannot stat file; treat as corrupt
                with open(corrupt_log, 'a') as f:
                    f.write(f"STAT_ERROR: {full_path}\n")
                continue

            # try reading header / rows
            try:
                df = pd.read_csv(full_path, nrows=5, low_memory=False)
            except Exception as e:
                with open(corrupt_log, 'a') as f:
                    f.write(f"{full_path}  ERROR: {e}\n")
                continue

            # check if it has zero data rows (read full if small)
            try:
                # get actual row count efficiently
                row_count = sum(1 for _ in open(full_path, 'r', errors='ignore')) - 1  # subtract header
            except Exception:
                row_count = df.shape[0]

            if row_count <= 0:
                with open(no_rows_log, 'a') as f:
                    f.write(f"{full_path}\n")
                continue

            # optionally: if all values in first few rows are NaN (poor data)
            if df.shape[0] > 0 and df.dropna(how='all').shape[0] == 0:
                with open(no_rows_log, 'a') as f:
                    f.write(f"{full_path}  ALL_NAN\n")

    print("Done. Logs:")
    print(f"  empty zero-byte files: {empty_log}")
    print(f"  corrupt/unreadable files: {corrupt_log}")
    print(f"  no-data / all-NaN files: {no_rows_log}")


if __name__ == "__main__":
    base_path = r"E:\DS_RAW_COMPLETE\DS_Structured"
    if os.path.exists(base_path):
        log_empty_csvs(base_path)
    else:
        print("❌ Base path does not exist!")
# Out:
# Done. Logs:
#   empty zero-byte files: E:\DS_RAW_COMPLETE\logs\6-empty_csv_files_log.txt
#   corrupt/unreadable files: E:\DS_RAW_COMPLETE\logs\6-corrupt_csv_files_log.txt
#   no-data / all-NaN files: E:\DS_RAW_COMPLETE\logs\6-no_rows_csv_files_log.txt

# %%
sensor_frequency = {
    'glass_accelerometer': 5,
    'glass_gyroscope': 5,
    'glass_magnetometer': 5,
    'phone_acceleromter_calibrated' : 100,
    'phone_accelerometer': 500,
    'phone_gravity': 200,
    'phone_linear_acceleration': 100,
    'phone_gyroscope_uncalibrated': 500,
    'phone_gyroscope': 500,
    'phone_magnetometer_uncalibrated': 100,
    'phone_magnetometer':  100,
    'phone_interrupt_gyroscope': 100,
    'watch_accelerometer': 100,
    'watch_gyroscope_uncalibrated': 200,
    'watch_linear_acceleration': 100,
    'watch_gyroscope': 100,
    'watch_magnetometer_uncalibrated': 100,
    'watch_magnetometer': 100,
    'watch_gravity': 100,
}
