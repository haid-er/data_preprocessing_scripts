# %%
import pandas as pd
import numpy as np
from pathlib import Path
from dataclasses import dataclass, asdict

SENSOR_RATES = {
    "glass_accelerometer": 5, "glass_gyroscope": 5, "glass_magnetometer": 5,
    "phone_acceleromter_calibrated": 100, "phone_accelerometer": 500,
    "phone_gravity": 200, "phone_linear_acceleration": 100,
    "phone_gyroscope_uncalibrated": 500, "phone_gyroscope": 500,
    "phone_magnetometer_uncalibrated": 100, "phone_magnetometer": 100,
    "phone_interrupt_gyroscope": 100, "watch_accelerometer": 100,
    "watch_gyroscope_uncalibrated": 200, "watch_linear_acceleration": 100,
    "watch_gyroscope": 100, "watch_magnetometer_uncalibrated": 100,
    "watch_magnetometer": 100, "watch_gravity": 100,
}
REFERENCE_KEYWORDS = ("accelerometer", "gyroscope", "magnetometer")
ALLOWED_ACTIVITIES = {
    "quick_walk","jogging","laying","reading","sitting","slow_walk","standing",
    "talk_using_phone","typing","walking","clean_the_table"
}
TARGET_MS, MIN_MS, AVG_DELTA_N = 180_000, 10_000, 5
REPORT_FILE = "report.csv"

# %%
@dataclass
class ReportRow:
    file_path: str
    sensor: str
    original_rows: int
    final_rows: int
    orig_start: int
    orig_end: int
    final_start: int
    final_end: int
    action: str
    warnings: str
    dropped_rows: int
    nan_rows: int
    mismatch_rate: float

# %%
def read_csv(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, header=None, usecols=[0,1,2,3],
                     names=["t","x","y","z"], na_values=["","NA","nan"])
    nan_rows = df.isna().any(axis=1).sum()
    df = df.dropna(how="all")
    # timestamp normalization
    df["t"] = pd.to_numeric(df["t"], errors="coerce") * (1000 if df["t"].max()<1e11 else 1)
    df = df.dropna(subset=["t"])
    df = df.astype({"t":"int64"})
    df[["x","y","z"]] = df[["x","y","z"]].apply(pd.to_numeric, errors="coerce")
    dropped_rows = len(df) - df.dropna().shape[0]
    return df.dropna().reset_index(drop=True), dropped_rows, nan_rows

def ensure_monotonic(df: pd.DataFrame) -> pd.DataFrame:
    diffs = df["t"].diff().dropna()
    mismatch_rate = (diffs <= 0).mean() if not diffs.empty else 0.0
    eps = max(1, int(diffs.tail(AVG_DELTA_N).mean()/10)) if not diffs.empty else 1
    df = df.sort_values("t").reset_index(drop=True)
    for i in range(1,len(df)):
        if df.at[i,"t"] <= df.at[i-1,"t"]:
            df.at[i,"t"] = df.at[i-1,"t"] + eps
    return df, mismatch_rate

# %%
def extend_to_target(df: pd.DataFrame) -> pd.DataFrame:
    base, avg = df["t"].iloc[0], int(df["t"].diff().mean())
    while df["t"].iloc[-1] - base < TARGET_MS:
        chunk = df.copy()
        chunk["t"] += df["t"].iloc[-1] + avg - chunk["t"].iloc[0]
        df = pd.concat([df, chunk])
    return df[df["t"] <= base+TARGET_MS].reset_index(drop=True)

def finalize(df: pd.DataFrame) -> pd.DataFrame:
    base, desired = df["t"].iloc[0], df["t"].iloc[0]+TARGET_MS
    if df["t"].iloc[-1] < desired:
        row = df.iloc[[-1]].copy()
        row["t"] = desired
        df = pd.concat([df, row])
    df.at[len(df)-1,"t"] = desired
    return df

# %%
def process_file(path: Path, sensor: str, dry: bool) -> ReportRow:
    try:
        df, dropped, nan_rows = read_csv(path)
    except Exception as e:
        return ReportRow(str(path), sensor,0,0,0,0,0,0,"read_failed", str(e),0,0,0.0)
    if df.empty:
        return ReportRow(str(path), sensor,0,0,0,0,0,0,"empty","",0,0,0.0)

    orig_rows, start, end = len(df), df["t"].iloc[0], df["t"].iloc[-1]
    dur = end-start
    if dur < MIN_MS:
        return ReportRow(str(path), sensor,orig_rows,0,start,end,0,0,"too_short","",dropped,nan_rows,0.0)
    if dur > TARGET_MS:
        df = df[df["t"] <= start+TARGET_MS]

    df, mismatch_rate = ensure_monotonic(df)
    if dur < TARGET_MS:
        df = extend_to_target(df)
    df = finalize(df)

    final_rows = len(df)
    warnings = []
    if final_rows < orig_rows:
        warnings.append("row_reduction")

    if not dry:
        df.to_csv(path, index=False, header=False)

    return ReportRow(
        str(path), sensor, orig_rows, final_rows, start, end,
        int(df["t"].iloc[0]), int(df["t"].iloc[-1]),
        "processed", ";".join(warnings), dropped, nan_rows, mismatch_rate
    )

# %%
def process_all(base: Path, dry=False):
    reports = []
    for folder in base.rglob("*"):
        if not folder.is_dir() or folder.name not in ALLOWED_ACTIVITIES:
            continue
        for sensor in SENSOR_RATES:
            matches = [f for f in folder.glob("*.csv") if sensor in f.name.lower()]
            if not matches: 
                continue
            reports.append(process_file(matches[0], sensor, dry))
    df_report = pd.DataFrame([asdict(r) for r in reports])
    out = base / REPORT_FILE
    df_report.to_csv(out, index=False)
    return df_report

# %%
# Example usage (dry-run mode)
base_path = Path(r"C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data")
report = process_all(base_path, dry=False)

# %%
report.head()
# Out:
#                                            file_path               sensor  \
# 0  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# 1  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...      glass_gyroscope
# 2  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
# 3  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  phone_accelerometer
# 4  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...        phone_gravity
#
#    original_rows  final_rows     orig_start       orig_end    final_start  \
# 0            435         899  1750134569750  1750134656873  1750134569750
# 1            420         899  1750134569750  1750134653858  1750134569750
# 2            419         899  1750134569750  1750134653678  1750134569750
# 3          89757       89942  1750134569636  1750134749271  1750134569636
# 4          17731       17994  1750134569635  1750134747022  1750134569635
#
#        final_end     action warnings  dropped_rows  nan_rows  mismatch_rate
# 0  1750134749750  processed                      0         0       0.000000
# 1  1750134749750  processed                      0         0       0.000000
# 2  1750134749750  processed                      0         0       0.000000
# 3  1750134749636  processed                      0         0       0.134465
# 4  1750134749635  processed                      0         0       0.000056

# %%
import os
import re
import glob
import math
import argparse
import logging
from pathlib import Path
from typing import Optional, Tuple, List, Dict, Any

import numpy as np
import pandas as pd

SENSOR_RATES = {
    "glass_accelerometer": 5, "glass_gyroscope": 5, "glass_magnetometer": 5,
    "phone_acceleromter_calibrated": 100, "phone_accelerometer": 500,
    "phone_gravity": 200, "phone_linear_acceleration": 100,
    "phone_gyroscope_uncalibrated": 500, "phone_gyroscope": 500,
    "phone_magnetometer_uncalibrated": 100, "phone_magnetometer": 100,
    "phone_interrupt_gyroscope": 100, "watch_accelerometer": 100,
    "watch_gyroscope_uncalibrated": 200, "watch_linear_acceleration": 100,
    "watch_gyroscope": 100, "watch_magnetometer_uncalibrated": 100,
    "watch_magnetometer": 100, "watch_gravity": 100,
}

TOTAL_CHUNKS = 36
CHUNK_MS = 5_000
CHUNK_DURATION_S = CHUNK_MS / 1000.0
TARGET_MS = TOTAL_CHUNKS * CHUNK_MS  # expected original length: 180_000 ms (180s)
REPORT_FILENAME = "report.csv"

# Logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s: %(message)s")


# ---------------------------
# Utilities
# ---------------------------

def guess_sensor_from_filename(fname: str, sensors_map: Dict[str, int]) -> Optional[str]:
    """
    Return the best matching sensor key if any substring matches.
    """
    lower = fname.lower()
    for key in sensors_map:
        if key in lower:
            return key
    # also try replacing '-' or spaces with underscores
    lower_norm = lower.replace("-", "_").replace(" ", "_")
    for key in sensors_map:
        if key in lower_norm:
            return key
    return None


def read_sensor_csv(path: Path) -> Tuple[pd.DataFrame, int, int]:
    """
    Read CSV robustly. Returns (df, dropped_rows_count, nan_rows_count).
    Assumes first 4 columns are t,x,y,z (no header usually).
    Converts timestamps if necessary (seconds -> ms).
    Drops rows that have no timestamp.
    """
    # read first 4 columns, tolerant to different formats
    try:
        df = pd.read_csv(path, header=None, usecols=[0, 1, 2, 3], names=["t", "x", "y", "z"],
                         dtype={0: object, 1: object, 2: object, 3: object}, na_values=["", "NA", "nan"])
    except Exception as e:
        # fallback: try without usecols (some files may have different column count)
        df = pd.read_csv(path, header=None, names=["t", "x", "y", "z"], na_values=["", "NA", "nan"])
        df = df.iloc[:, :4]
        df.columns = ["t", "x", "y", "z"]

    # count rows with any NaN (before dropping)
    nan_rows = df.isna().any(axis=1).sum()

    # drop rows where all are NaN
    df = df.dropna(how="all").copy()

    # normalize timestamp column: numeric coercion
    df["t"] = pd.to_numeric(df["t"], errors="coerce")

    # convert seconds -> milliseconds if the timestamps look like seconds
    # typical epoch in ms is > 1e11; if max timestamp is < 1e11 assume seconds
    if not df["t"].empty:
        max_t = df["t"].max()
        if max_t is not None and max_t < 1e11:
            df["t"] = df["t"] * 1000.0

    df = df.dropna(subset=["t"]).copy()
    df["t"] = df["t"].astype("int64")
    # ensure numeric x,y,z
    df[["x", "y", "z"]] = df[["x", "y", "z"]].apply(pd.to_numeric, errors="coerce")
    # how many rows had numeric problems (x,y,z) - we keep them (they may be NaN) but count dropped later if needed
    dropped_rows = 0  # we don't drop partially numeric rows here
    df = df.reset_index(drop=True)
    return df, dropped_rows, int(nan_rows)


def estimate_rate_from_df(df: pd.DataFrame, fallback: int = 50) -> int:
    """
    Estimate sampling rate (Hz) from median delta of timestamps.
    """
    if len(df) < 2:
        return fallback
    deltas = df["t"].diff().dropna()
    # use median to be robust
    median_ms = deltas.median()
    if pd.isna(median_ms) or median_ms <= 0:
        return fallback
    est_rate = int(round(1000.0 / median_ms))
    return max(1, est_rate)


def ensure_monotonic_timestamps(df: pd.DataFrame, min_step_ms: int = 1) -> Tuple[pd.DataFrame, float]:
    """
    Sort by timestamp and make strictly increasing by enforcing minimum step (min_step_ms).
    Returns corrected df and mismatch_rate (fraction of non-increasing deltas in the original).
    """
    if df.empty or len(df) < 2:
        return df, 0.0
    # compute mismatch rate before sort
    diffs = df["t"].diff().dropna()
    mismatch_rate = float((diffs <= 0).mean()) if not diffs.empty else 0.0

    # sort
    df = df.sort_values("t").reset_index(drop=True)
    # repair equal or decreasing timestamps
    for i in range(1, len(df)):
        if df.at[i, "t"] <= df.at[i-1, "t"]:
            df.at[i, "t"] = df.at[i-1, "t"] + min_step_ms
    return df, mismatch_rate


# ---------------------------
# Core splitting logic
# ---------------------------

def create_chunk_rows(original_df: pd.DataFrame, window_start: int, window_end: int, target_rows: int) -> pd.DataFrame:
    """
    Build a chunk dataframe of exactly target_rows rows for the time window [window_start, window_end).
    Padding: copy from start of the original file (cycling if necessary).
    After assembling x,y,z values, timestamps are overwritten with evenly spaced ints over [window_start, window_end-1].
    The returned df has columns ['t','x','y','z'].
    """
    # select rows that fall into the window
    mask = (original_df["t"] >= window_start) & (original_df["t"] < window_end)
    chunk = original_df.loc[mask, ["x", "y", "z"]].copy().reset_index(drop=True)

    available = len(chunk)
    needed = target_rows - available

    if needed > 0:
        # pad from the start of the file as required, cycling if needed
        # take values only (x,y,z) from the original df start
        source = original_df[["x", "y", "z"]].reset_index(drop=True)
        if source.empty:
            # Create zeros if file is empty - improbable but safe fallback
            pad_vals = pd.DataFrame(np.zeros((needed, 3)), columns=["x", "y", "z"])
        else:
            # repeat source rows until we have enough
            reps = int(math.ceil(needed / len(source)))
            padded_pool = pd.concat([source] * reps, ignore_index=True)
            pad_vals = padded_pool.iloc[:needed].reset_index(drop=True)
        chunk = pd.concat([chunk, pad_vals], ignore_index=True)

    # trim extra just in case
    if len(chunk) > target_rows:
        chunk = chunk.iloc[:target_rows].reset_index(drop=True)

    # assign evenly spaced timestamps across [window_start, window_end-1]
    ts = np.linspace(window_start, window_end - 1, target_rows)
    ts = np.round(ts).astype("int64")
    chunk.insert(0, "t", ts)
    return chunk


def split_file_into_chunks(path: Path, rate_hz: int, total_chunks: int = TOTAL_CHUNKS, chunk_ms: int = CHUNK_MS) -> Tuple[List[Path], List[Dict[str, Any]]]:
    """
    Split the 180s file into `total_chunks` files. Returns list of output paths and a list of metadata dicts
    (one dict per chunk) for reporting.
    """
    df, dropped_rows, nan_rows = read_sensor_csv(path)
    if df.empty:
        raise ValueError(f"File {path} has no valid rows after reading.")

    # Ensure timestamps are monotonically increasing
    df, mismatch_rate = ensure_monotonic_timestamps(df)

    start_ts = int(df["t"].iloc[0])
    target_rows = int(rate_hz * (chunk_ms / 1000.0))

    out_paths = []
    report_rows = []

    # ensure the original covers at least 180s? If shorter, we will cycle/pad across windows
    for i in range(total_chunks):
        chunk_start = start_ts + i * chunk_ms
        chunk_end = chunk_start + chunk_ms
        chunk_df = create_chunk_rows(df, chunk_start, chunk_end, target_rows)

        # final safety: ensure exactly target_rows and timestamps strictly increasing
        if len(chunk_df) != target_rows:
            chunk_df = chunk_df.iloc[:target_rows].reset_index(drop=True)

        chunk_df, _ = ensure_monotonic_timestamps(chunk_df, min_step_ms=max(1, int(chunk_df["t"].diff().median() or 1)))
        out_name = f"{path.stem}_e{i+1}.csv"
        out_path = path.with_name(out_name)
        # write
        chunk_df.to_csv(out_path, index=False, header=False)
        out_paths.append(out_path)

        # record report row
        report_rows.append({
            "orig_file": str(path),
            "sensor": path.stem,
            "rate_hz": rate_hz,
            "chunk_index": i + 1,
            "chunk_start": chunk_start,
            "chunk_end": chunk_end,
            "rows_written": len(chunk_df),
            "padded": int(len(chunk_df) != ((df["t"] >= chunk_start) & (df["t"] < chunk_end)).sum()),
            "out_path": str(out_path),
            "dropped_rows_in_read": dropped_rows,
            "nan_rows_in_read": nan_rows,
            "mismatch_rate_before_fix": mismatch_rate,
        })

    return out_paths, report_rows


# ---------------------------
# High level processing
# ---------------------------

def process_file(path: Path, sensor_rates_map: Dict[str, int], remove_original: bool = False, dry_run: bool = True) -> List[Dict[str, Any]]:
    """
    Process a single file. Returns list of per-chunk report dicts.
    """
    fname = path.name
    # skip already-split files
    if re.search(r"_e\d+\.csv$", fname):
        logging.debug(f"Skipping already-chunked file: {path}")
        return []

    # try to guess sensor type from filename
    sensor_key = guess_sensor_from_filename(fname, sensor_rates_map)
    # fallback - try to use stem exact match
    if sensor_key is None:
        sensor_key = guess_sensor_from_filename(path.stem, sensor_rates_map)

    # read to estimate rate if needed
    df, dropped_rows, nan_rows = read_sensor_csv(path)
    if df.empty:
        logging.warning(f"Skipping empty/invalid file: {path}")
        return [{
            "orig_file": str(path),
            "error": "empty_or_invalid_file",
            "dropped_rows": dropped_rows,
            "nan_rows": nan_rows
        }]

    # choose rate
    if sensor_key:
        rate = sensor_rates_map[sensor_key]
        logging.info(f"Using mapped rate {rate}Hz for {sensor_key} (file: {fname})")
    else:
        rate = estimate_rate_from_df(df, fallback=50)
        logging.info(f"No mapping for '{fname}' — estimated rate {rate}Hz")

    # if the original file is shorter/longer than expected, we won't try to trim here; splitting windows are anchored to start timestamp
    # call split
    try:
        # we pass the already-read df by writing it temporarily to ensure single read? To keep code simple we call split_file_into_chunks which reads again.
        out_paths, report_rows = split_file_into_chunks(path, rate, total_chunks=TOTAL_CHUNKS, chunk_ms=CHUNK_MS)
        # optionally remove original
        if remove_original and not dry_run:
            try:
                path.unlink()
                logging.info(f"Removed original file: {path}")
            except Exception as e:
                logging.warning(f"Could not remove original {path}: {e}")
        # annotate reports with orig file-level fields
        for r in report_rows:
            r["orig_rows"] = len(df)
            r["orig_start"] = int(df["t"].iloc[0])
            r["orig_end"] = int(df["t"].iloc[-1])
        return report_rows
    except Exception as e:
        logging.exception(f"Failed to split file {path}: {e}")
        return [{
            "orig_file": str(path),
            "error": str(e)
        }]


def process_all(base: Path, sensor_rates_map: Dict[str, int], remove_original: bool = False, dry_run: bool = True, recurse: bool = True):
    """
    Walk the base path (files if file provided or folder recursively) and process sensor CSVs.
    Produces a report CSV at base/REPORT_FILENAME (if base is a directory) or in the file's parent.
    Returns pandas DataFrame of report.
    """
    base = Path(base)
    report_rows: List[Dict[str, Any]] = []

    if base.is_file():
        report_rows.extend(process_file(base, sensor_rates_map, remove_original=remove_original, dry_run=dry_run))
        out_dir = base.parent
    else:
        # recurse search for CSVs
        pattern = "**/*.csv" if recurse else "*.csv"
        files = list(base.glob(pattern))
        files = [p for p in files if not re.search(r"_e\d+\.csv$", p.name)]  # skip already chunked
        logging.info(f"Found {len(files)} csv files under {base}")
        for f in files:
            try:
                rows = process_file(f, sensor_rates_map, remove_original=remove_original, dry_run=dry_run)
                report_rows.extend(rows)
            except Exception as e:
                logging.exception(f"Error processing {f}: {e}")
        out_dir = base

    if report_rows:
        df_report = pd.DataFrame(report_rows)
    else:
        df_report = pd.DataFrame(columns=[
            "orig_file", "sensor", "rate_hz", "chunk_index", "chunk_start", "chunk_end",
            "rows_written", "padded", "out_path", "dropped_rows_in_read", "nan_rows_in_read",
            "mismatch_rate_before_fix", "orig_rows", "orig_start", "orig_end"
        ])
    # write out CSV
    report_path = out_dir / REPORT_FILENAME
    if not dry_run:
        df_report.to_csv(report_path, index=False)
        logging.info(f"Wrote report to {report_path}")
    else:
        logging.info("Dry run enabled — not writing report file to disk.")

    return df_report

# %%
from pathlib import Path
base_path = Path(r"C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data")
report = process_all(base_path, SENSOR_RATES, remove_original=True, dry_run=False)
# Out:
# 2025-09-19 23:42:32,090 INFO: Found 602 csv files under C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data
# 2025-09-19 23:42:32,187 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:42:32,720 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\glass_accelerometer.csv
# 2025-09-19 23:42:32,787 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:42:33,281 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\glass_gyroscope.csv
# 2025-09-19 23:42:33,346 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:42:33,827 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\glass_magnetometer.csv
# 2025-09-19 23:42:34,489 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:42:43,510 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_accelerometer.csv
# 2025-09-19 23:42:43,645 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:42:47,188 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_accelerometer_calibrated.csv
# 2025-09-19 23:42:47,311 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:42:49,281 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_gravity.csv
# 2025-09-19 23:42:49,824 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:42:56,997 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_gyroscope.csv
# 2025-09-19 23:42:57,505 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:43:04,212 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:43:04,257 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:43:05,002 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_interrupt_gyroscope.csv
# 2025-09-19 23:43:05,136 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:43:06,022 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_linear_acceleration.csv
# 2025-09-19 23:43:06,108 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:43:06,977 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_magnetometer.csv
# 2025-09-19 23:43:07,090 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:43:08,153 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:43:08,270 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:43:09,192 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_accelerometer.csv
# 2025-09-19 23:43:09,339 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:43:10,222 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_gravity.csv
# 2025-09-19 23:43:10,343 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:43:11,253 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_gyroscope.csv
# 2025-09-19 23:43:11,460 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:43:12,934 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:43:13,058 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:43:14,154 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_linear_acceleration.csv
# 2025-09-19 23:43:14,293 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:43:15,220 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_magnetometer.csv
# 2025-09-19 23:43:15,341 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:43:16,479 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\clean_the_table\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:43:16,494 WARNING: Skipping empty/invalid file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\glass_accelerometer.csv
# 2025-09-19 23:43:16,509 WARNING: Skipping empty/invalid file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\glass_gyroscope.csv
# 2025-09-19 23:43:16,523 WARNING: Skipping empty/invalid file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\glass_magnetometer.csv
# 2025-09-19 23:43:17,202 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:43:22,882 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_accelerometer.csv
# 2025-09-19 23:43:23,065 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:43:25,828 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_accelerometer_calibrated.csv
# 2025-09-19 23:43:25,977 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:43:27,427 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_gravity.csv
# 2025-09-19 23:43:27,956 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:43:32,422 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_gyroscope.csv
# 2025-09-19 23:43:32,930 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:43:37,604 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:43:37,673 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:43:38,454 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_interrupt_gyroscope.csv
# 2025-09-19 23:43:38,647 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:43:39,495 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_linear_acceleration.csv
# 2025-09-19 23:43:39,611 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:43:40,529 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_magnetometer.csv
# 2025-09-19 23:43:40,692 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:43:41,725 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:43:41,874 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:43:42,752 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_accelerometer.csv
# 2025-09-19 23:43:42,874 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:43:43,850 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_gravity.csv
# 2025-09-19 23:43:43,935 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:43:44,763 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_gyroscope.csv
# 2025-09-19 23:43:45,038 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:43:46,511 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:43:46,582 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:43:47,329 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_linear_acceleration.csv
# 2025-09-19 23:43:47,460 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:43:48,267 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_magnetometer.csv
# 2025-09-19 23:43:48,369 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:43:49,063 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\jogging\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:43:49,089 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:43:49,352 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\glass_accelerometer.csv
# 2025-09-19 23:43:49,379 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:43:49,606 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\glass_gyroscope.csv
# 2025-09-19 23:43:49,631 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:43:49,866 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\glass_magnetometer.csv
# 2025-09-19 23:43:50,445 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:43:54,692 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_accelerometer.csv
# 2025-09-19 23:43:54,795 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:43:56,818 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_accelerometer_calibrated.csv
# 2025-09-19 23:43:56,938 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:43:58,228 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_gravity.csv
# 2025-09-19 23:43:58,726 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:44:03,067 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_gyroscope.csv
# 2025-09-19 23:44:03,529 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:44:07,104 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:44:07,229 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:44:08,005 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_linear_acceleration.csv
# 2025-09-19 23:44:08,102 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:44:08,836 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_magnetometer.csv
# 2025-09-19 23:44:08,942 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:44:09,577 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:44:09,652 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:44:10,362 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_accelerometer.csv
# 2025-09-19 23:44:10,531 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:44:11,267 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_gravity.csv
# 2025-09-19 23:44:11,397 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:44:12,150 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_gyroscope.csv
# 2025-09-19 23:44:12,309 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:44:13,568 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:44:13,653 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:44:14,462 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_linear_acceleration.csv
# 2025-09-19 23:44:14,583 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:44:15,195 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_magnetometer.csv
# 2025-09-19 23:44:15,267 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:44:15,836 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\laying\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:44:15,858 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:44:16,013 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\glass_accelerometer.csv
# 2025-09-19 23:44:16,041 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:44:16,221 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\glass_gyroscope.csv
# 2025-09-19 23:44:16,244 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:44:16,463 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\glass_magnetometer.csv
# 2025-09-19 23:44:16,849 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:44:21,418 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_accelerometer.csv
# 2025-09-19 23:44:21,568 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:44:23,998 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_accelerometer_calibrated.csv
# 2025-09-19 23:44:24,150 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:44:25,227 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_gravity.csv
# 2025-09-19 23:44:25,626 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:44:29,657 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_gyroscope.csv
# 2025-09-19 23:44:30,207 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:44:34,289 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:44:34,348 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:44:34,861 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_interrupt_gyroscope.csv
# 2025-09-19 23:44:34,972 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:44:35,605 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_linear_acceleration.csv
# 2025-09-19 23:44:35,684 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:44:36,267 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_magnetometer.csv
# 2025-09-19 23:44:36,349 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:44:37,093 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:44:37,218 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:44:37,909 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_accelerometer.csv
# 2025-09-19 23:44:38,029 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:44:38,942 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_gravity.csv
# 2025-09-19 23:44:39,068 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:44:39,966 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_gyroscope.csv
# 2025-09-19 23:44:40,138 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:44:41,633 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:44:41,787 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:44:42,494 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_linear_acceleration.csv
# 2025-09-19 23:44:42,602 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:44:43,332 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_magnetometer.csv
# 2025-09-19 23:44:43,457 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:44:44,209 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\quick_walk\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:44:44,240 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:44:44,509 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\glass_accelerometer.csv
# 2025-09-19 23:44:44,542 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:44:44,781 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\glass_gyroscope.csv
# 2025-09-19 23:44:44,809 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:44:45,024 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\glass_magnetometer.csv
# 2025-09-19 23:44:45,398 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:44:49,171 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_accelerometer.csv
# 2025-09-19 23:44:49,251 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:44:50,873 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_accelerometer_calibrated.csv
# 2025-09-19 23:44:50,969 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:44:51,854 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_gravity.csv
# 2025-09-19 23:44:52,194 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:44:55,799 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_gyroscope.csv
# 2025-09-19 23:44:56,274 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:44:59,737 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:44:59,859 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:45:00,524 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_linear_acceleration.csv
# 2025-09-19 23:45:00,632 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:45:01,275 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_magnetometer.csv
# 2025-09-19 23:45:01,358 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:45:02,166 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:45:02,261 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:45:03,041 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_accelerometer.csv
# 2025-09-19 23:45:03,163 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:45:03,939 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_gravity.csv
# 2025-09-19 23:45:04,031 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:45:04,774 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_gyroscope.csv
# 2025-09-19 23:45:04,945 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:45:06,386 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:45:06,481 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:45:07,093 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_linear_acceleration.csv
# 2025-09-19 23:45:07,174 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:45:07,838 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_magnetometer.csv
# 2025-09-19 23:45:07,928 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:45:08,570 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\reading\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:45:08,602 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:45:08,800 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\glass_accelerometer.csv
# 2025-09-19 23:45:08,828 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:45:09,081 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\glass_gyroscope.csv
# 2025-09-19 23:45:09,119 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:45:09,382 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\glass_magnetometer.csv
# 2025-09-19 23:45:09,846 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:45:13,706 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_accelerometer.csv
# 2025-09-19 23:45:13,810 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:45:15,373 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_accelerometer_calibrated.csv
# 2025-09-19 23:45:15,509 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:45:16,495 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_gravity.csv
# 2025-09-19 23:45:16,924 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:45:21,212 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_gyroscope.csv
# 2025-09-19 23:45:21,849 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:45:26,384 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:45:26,589 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:45:27,556 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_linear_acceleration.csv
# 2025-09-19 23:45:27,637 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:45:28,287 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_magnetometer.csv
# 2025-09-19 23:45:28,389 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:45:29,231 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:45:29,339 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:45:30,024 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_accelerometer.csv
# 2025-09-19 23:45:30,123 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:45:30,877 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_gravity.csv
# 2025-09-19 23:45:30,995 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:45:31,687 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_gyroscope.csv
# 2025-09-19 23:45:31,832 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:45:33,032 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:45:33,113 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:45:33,772 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_linear_acceleration.csv
# 2025-09-19 23:45:33,844 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:45:34,553 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_magnetometer.csv
# 2025-09-19 23:45:34,634 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:45:35,299 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\sitting\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:45:35,326 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:45:35,590 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\glass_accelerometer.csv
# 2025-09-19 23:45:35,625 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:45:35,956 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\glass_gyroscope.csv
# 2025-09-19 23:45:35,984 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:45:36,167 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\glass_magnetometer.csv
# 2025-09-19 23:45:36,594 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:45:40,205 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_accelerometer.csv
# 2025-09-19 23:45:40,291 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:45:42,028 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_accelerometer_calibrated.csv
# 2025-09-19 23:45:42,154 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:45:43,288 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_gravity.csv
# 2025-09-19 23:45:43,777 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:45:48,008 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_gyroscope.csv
# 2025-09-19 23:45:48,529 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:45:52,914 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:45:52,991 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:45:53,513 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_interrupt_gyroscope.csv
# 2025-09-19 23:45:53,664 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:45:54,976 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_linear_acceleration.csv
# 2025-09-19 23:45:55,099 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:45:56,489 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_magnetometer.csv
# 2025-09-19 23:45:56,745 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:45:57,778 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:45:57,900 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:45:58,918 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_accelerometer.csv
# 2025-09-19 23:45:59,074 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:46:00,244 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_gravity.csv
# 2025-09-19 23:46:00,376 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:46:01,085 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_gyroscope.csv
# 2025-09-19 23:46:01,243 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:46:02,560 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:46:02,648 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:46:03,468 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_linear_acceleration.csv
# 2025-09-19 23:46:03,549 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:46:04,371 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_magnetometer.csv
# 2025-09-19 23:46:04,460 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:46:05,137 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\slow_walk\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:46:05,171 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:46:05,376 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\glass_accelerometer.csv
# 2025-09-19 23:46:05,410 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:46:05,664 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\glass_gyroscope.csv
# 2025-09-19 23:46:05,691 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:46:05,941 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\glass_magnetometer.csv
# 2025-09-19 23:46:06,521 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:46:11,097 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_accelerometer.csv
# 2025-09-19 23:46:11,212 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:46:14,001 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_accelerometer_calibrated.csv
# 2025-09-19 23:46:14,143 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:46:15,861 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_gravity.csv
# 2025-09-19 23:46:16,507 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:46:22,749 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_gyroscope.csv
# 2025-09-19 23:46:23,264 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:46:28,309 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:46:28,456 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:46:29,220 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_linear_acceleration.csv
# 2025-09-19 23:46:29,324 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:46:30,084 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_magnetometer.csv
# 2025-09-19 23:46:30,181 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:46:30,967 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:46:31,075 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:46:31,892 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_accelerometer.csv
# 2025-09-19 23:46:32,065 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:46:33,023 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_gravity.csv
# 2025-09-19 23:46:33,127 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:46:33,934 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_gyroscope.csv
# 2025-09-19 23:46:34,139 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:46:35,414 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:46:35,539 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:46:36,499 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_linear_acceleration.csv
# 2025-09-19 23:46:36,588 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:46:37,303 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_magnetometer.csv
# 2025-09-19 23:46:37,408 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:46:38,326 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\standing\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:46:38,370 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:46:38,623 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\glass_accelerometer.csv
# 2025-09-19 23:46:38,662 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:46:38,991 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\glass_gyroscope.csv
# 2025-09-19 23:46:39,028 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:46:39,312 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\glass_magnetometer.csv
# 2025-09-19 23:46:39,838 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:46:43,919 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_accelerometer.csv
# 2025-09-19 23:46:44,019 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:46:46,188 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_accelerometer_calibrated.csv
# 2025-09-19 23:46:46,366 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:46:47,605 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_gravity.csv
# 2025-09-19 23:46:48,079 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:46:53,604 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_gyroscope.csv
# 2025-09-19 23:46:54,183 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:47:00,950 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:47:00,991 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:47:01,943 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_interrupt_gyroscope.csv
# 2025-09-19 23:47:02,300 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:47:03,380 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_linear_acceleration.csv
# 2025-09-19 23:47:03,516 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:47:04,778 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_magnetometer.csv
# 2025-09-19 23:47:04,966 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:47:06,303 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:47:06,396 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:47:07,527 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_accelerometer.csv
# 2025-09-19 23:47:07,650 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:47:08,547 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_gravity.csv
# 2025-09-19 23:47:08,608 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:47:09,412 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_gyroscope.csv
# 2025-09-19 23:47:09,561 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:47:10,829 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:47:10,903 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:47:11,668 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_linear_acceleration.csv
# 2025-09-19 23:47:11,741 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:47:12,557 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_magnetometer.csv
# 2025-09-19 23:47:12,628 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:47:13,390 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\talk_using_phone\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:47:13,432 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:47:13,711 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\glass_accelerometer.csv
# 2025-09-19 23:47:13,747 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:47:14,019 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\glass_gyroscope.csv
# 2025-09-19 23:47:14,108 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:47:14,400 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\glass_magnetometer.csv
# 2025-09-19 23:47:14,931 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:47:20,632 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\phone_accelerometer.csv
# 2025-09-19 23:47:20,747 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:47:23,287 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\phone_accelerometer_calibrated.csv
# 2025-09-19 23:47:23,468 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:47:24,824 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\phone_gravity.csv
# 2025-09-19 23:47:25,404 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:47:31,397 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\areeba\typing\phone_gyroscope.csv
# 2025-09-19 23:47:32,232 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# ...
# 2025-09-19 23:58:52,247 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:58:52,511 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\glass_gyroscope.csv
# 2025-09-19 23:58:52,545 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:58:52,792 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\glass_magnetometer.csv
# 2025-09-19 23:58:53,320 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:58:57,393 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_accelerometer.csv
# 2025-09-19 23:58:57,514 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:58:59,418 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_accelerometer_calibrated.csv
# 2025-09-19 23:58:59,554 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:59:00,513 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_gravity.csv
# 2025-09-19 23:59:01,062 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:59:05,288 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_gyroscope.csv
# 2025-09-19 23:59:05,781 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:59:10,185 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:59:10,226 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:59:10,947 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_interrupt_gyroscope.csv
# 2025-09-19 23:59:11,123 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:59:12,159 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_linear_acceleration.csv
# 2025-09-19 23:59:12,273 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:59:13,222 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_magnetometer.csv
# 2025-09-19 23:59:13,346 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:59:14,326 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:59:14,440 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:59:15,149 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_accelerometer.csv
# 2025-09-19 23:59:15,275 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:59:16,003 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_gravity.csv
# 2025-09-19 23:59:16,132 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:59:17,116 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_gyroscope.csv
# 2025-09-19 23:59:17,391 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:59:19,022 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:59:19,170 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:59:20,183 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_linear_acceleration.csv
# 2025-09-19 23:59:20,303 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:59:21,366 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_magnetometer.csv
# 2025-09-19 23:59:21,482 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:59:22,171 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\talk_using_phone\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:59:22,206 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:59:22,450 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\glass_accelerometer.csv
# 2025-09-19 23:59:22,484 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-19 23:59:22,791 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\glass_gyroscope.csv
# 2025-09-19 23:59:22,841 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-19 23:59:23,126 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\glass_magnetometer.csv
# 2025-09-19 23:59:23,598 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-19 23:59:29,090 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_accelerometer.csv
# 2025-09-19 23:59:29,268 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-19 23:59:31,719 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_accelerometer_calibrated.csv
# 2025-09-19 23:59:31,893 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-19 23:59:33,028 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_gravity.csv
# 2025-09-19 23:59:33,640 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-19 23:59:39,339 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_gyroscope.csv
# 2025-09-19 23:59:40,035 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-19 23:59:45,615 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_gyroscope_uncalibrated.csv
# 2025-09-19 23:59:45,682 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-19 23:59:46,507 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_interrupt_gyroscope.csv
# 2025-09-19 23:59:46,647 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-19 23:59:47,475 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_linear_acceleration.csv
# 2025-09-19 23:59:47,611 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-19 23:59:48,489 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_magnetometer.csv
# 2025-09-19 23:59:48,625 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-19 23:59:49,685 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\phone_magnetometer_uncalibrated.csv
# 2025-09-19 23:59:49,847 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-19 23:59:50,894 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_accelerometer.csv
# 2025-09-19 23:59:51,113 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-19 23:59:52,322 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_gravity.csv
# 2025-09-19 23:59:52,489 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-19 23:59:53,576 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_gyroscope.csv
# 2025-09-19 23:59:53,804 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-19 23:59:55,477 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_gyroscope_uncalibrated.csv
# 2025-09-19 23:59:55,626 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-19 23:59:56,813 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_linear_acceleration.csv
# 2025-09-19 23:59:56,945 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-19 23:59:58,039 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_magnetometer.csv
# 2025-09-19 23:59:58,216 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-19 23:59:59,311 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\typing\watch_magnetometer_uncalibrated.csv
# 2025-09-19 23:59:59,348 INFO: Using mapped rate 5Hz for glass_accelerometer (file: glass_accelerometer.csv)
# 2025-09-19 23:59:59,639 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\glass_accelerometer.csv
# 2025-09-19 23:59:59,677 INFO: Using mapped rate 5Hz for glass_gyroscope (file: glass_gyroscope.csv)
# 2025-09-20 00:00:00,010 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\glass_gyroscope.csv
# 2025-09-20 00:00:00,067 INFO: Using mapped rate 5Hz for glass_magnetometer (file: glass_magnetometer.csv)
# 2025-09-20 00:00:00,391 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\glass_magnetometer.csv
# 2025-09-20 00:00:01,057 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer.csv)
# 2025-09-20 00:00:04,946 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_accelerometer.csv
# 2025-09-20 00:00:05,078 INFO: Using mapped rate 500Hz for phone_accelerometer (file: phone_accelerometer_calibrated.csv)
# 2025-09-20 00:00:07,300 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_accelerometer_calibrated.csv
# 2025-09-20 00:00:07,484 INFO: Using mapped rate 200Hz for phone_gravity (file: phone_gravity.csv)
# 2025-09-20 00:00:08,868 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_gravity.csv
# 2025-09-20 00:00:09,410 INFO: Using mapped rate 500Hz for phone_gyroscope (file: phone_gyroscope.csv)
# 2025-09-20 00:00:14,108 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_gyroscope.csv
# 2025-09-20 00:00:14,647 INFO: Using mapped rate 500Hz for phone_gyroscope_uncalibrated (file: phone_gyroscope_uncalibrated.csv)
# 2025-09-20 00:00:18,908 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_gyroscope_uncalibrated.csv
# 2025-09-20 00:00:18,981 INFO: Using mapped rate 100Hz for phone_interrupt_gyroscope (file: phone_interrupt_gyroscope.csv)
# 2025-09-20 00:00:19,697 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_interrupt_gyroscope.csv
# 2025-09-20 00:00:19,823 INFO: Using mapped rate 100Hz for phone_linear_acceleration (file: phone_linear_acceleration.csv)
# 2025-09-20 00:00:20,540 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_linear_acceleration.csv
# 2025-09-20 00:00:20,656 INFO: Using mapped rate 100Hz for phone_magnetometer (file: phone_magnetometer.csv)
# 2025-09-20 00:00:21,593 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_magnetometer.csv
# 2025-09-20 00:00:21,748 INFO: Using mapped rate 100Hz for phone_magnetometer_uncalibrated (file: phone_magnetometer_uncalibrated.csv)
# 2025-09-20 00:00:22,527 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\phone_magnetometer_uncalibrated.csv
# 2025-09-20 00:00:22,651 INFO: Using mapped rate 100Hz for watch_accelerometer (file: watch_accelerometer.csv)
# 2025-09-20 00:00:23,595 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_accelerometer.csv
# 2025-09-20 00:00:23,748 INFO: Using mapped rate 100Hz for watch_gravity (file: watch_gravity.csv)
# 2025-09-20 00:00:24,864 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_gravity.csv
# 2025-09-20 00:00:25,056 INFO: Using mapped rate 100Hz for watch_gyroscope (file: watch_gyroscope.csv)
# 2025-09-20 00:00:26,299 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_gyroscope.csv
# 2025-09-20 00:00:26,566 INFO: Using mapped rate 200Hz for watch_gyroscope_uncalibrated (file: watch_gyroscope_uncalibrated.csv)
# 2025-09-20 00:00:28,019 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_gyroscope_uncalibrated.csv
# 2025-09-20 00:00:28,170 INFO: Using mapped rate 100Hz for watch_linear_acceleration (file: watch_linear_acceleration.csv)
# 2025-09-20 00:00:29,340 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_linear_acceleration.csv
# 2025-09-20 00:00:29,497 INFO: Using mapped rate 100Hz for watch_magnetometer (file: watch_magnetometer.csv)
# 2025-09-20 00:00:30,642 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_magnetometer.csv
# 2025-09-20 00:00:30,803 INFO: Using mapped rate 100Hz for watch_magnetometer_uncalibrated (file: watch_magnetometer_uncalibrated.csv)
# 2025-09-20 00:00:31,985 INFO: Removed original file: C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\bcsf21m531\walking\watch_magnetometer_uncalibrated.csv
# 2025-09-20 00:00:32,867 INFO: Wrote report to C:\Users\Malik Haider\Documents\HUMCARE\DATASET_FILLING\test_data\report.csv

# %%
report.head(100)
# Out:
#                                             orig_file               sensor  \
# 0   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# 1   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# 2   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# 3   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# 4   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...  glass_accelerometer
# ..                                                ...                  ...
# 95  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
# 96  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
# 97  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
# 98  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
# 99  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...   glass_magnetometer
#
#     rate_hz  chunk_index   chunk_start     chunk_end  rows_written  padded  \
# 0       5.0          1.0  1.750135e+12  1.750135e+12          25.0     1.0
# 1       5.0          2.0  1.750135e+12  1.750135e+12          25.0     1.0
# 2       5.0          3.0  1.750135e+12  1.750135e+12          25.0     0.0
# 3       5.0          4.0  1.750135e+12  1.750135e+12          25.0     0.0
# 4       5.0          5.0  1.750135e+12  1.750135e+12          25.0     0.0
# ..      ...          ...           ...           ...           ...     ...
# 95      5.0         24.0  1.750135e+12  1.750135e+12          25.0     1.0
# 96      5.0         25.0  1.750135e+12  1.750135e+12          25.0     1.0
# 97      5.0         26.0  1.750135e+12  1.750135e+12          25.0     1.0
# 98      5.0         27.0  1.750135e+12  1.750135e+12          25.0     1.0
# 99      5.0         28.0  1.750135e+12  1.750135e+12          25.0     1.0
#
#                                              out_path  dropped_rows_in_read  \
# 0   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 1   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 2   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 3   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 4   C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# ..                                                ...                   ...
# 95  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 96  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 97  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 98  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
# 99  C:\Users\Malik Haider\Documents\HUMCARE\DATASE...                   0.0
#
#     nan_rows_in_read  mismatch_rate_before_fix  orig_rows    orig_start  \
# 0                0.0                       0.0      435.0  1.750135e+12
# 1                0.0                       0.0      435.0  1.750135e+12
# 2                0.0                       0.0      435.0  1.750135e+12
# 3                0.0                       0.0      435.0  1.750135e+12
# 4                0.0                       0.0      435.0  1.750135e+12
# ..               ...                       ...        ...           ...
# 95               0.0                       0.0      419.0  1.750135e+12
# 96               0.0                       0.0      419.0  1.750135e+12
# 97               0.0                       0.0      419.0  1.750135e+12
# 98               0.0                       0.0      419.0  1.750135e+12
# 99               0.0                       0.0      419.0  1.750135e+12
#
#         orig_end error  dropped_rows  nan_rows
# 0   1.750135e+12   NaN           NaN       NaN
# 1   1.750135e+12   NaN           NaN       NaN
# 2   1.750135e+12   NaN           NaN       NaN
# 3   1.750135e+12   NaN           NaN       NaN
# 4   1.750135e+12   NaN           NaN       NaN
# ..           ...   ...           ...       ...
# 95  1.750135e+12   NaN           NaN       NaN
# 96  1.750135e+12   NaN           NaN       NaN
# 97  1.750135e+12   NaN           NaN       NaN
# 98  1.750135e+12   NaN           NaN       NaN
# 99  1.750135e+12   NaN           NaN       NaN
#
# [100 rows x 18 columns]
